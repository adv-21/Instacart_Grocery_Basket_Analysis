# %%
#importing libraries and data
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Stugots\Desktop\Bootcamp Stuff\Intro to Python\Instacart Basket Analysis 01-2025'

# %%
df_ords_comb = pd.read_pickle (os.path.join(path, '02 Data' , 'Prepared Data' , 'orders_products_combined.pkl'))

# %%
df_prods = pd.read_csv (os.path.join(path, '02 Data' , 'Prepared Data' , 'products_checked.csv'))

# %%
df_ords_comb.shape
# Out:
# (32434489, 12)

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_ords_comb.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_the_week  order_hour_of_day  days_since_prior_order  \
# 0                       2                  8                     NaN
# 1                       2                  8                     NaN
# 2                       2                  8                     NaN
# 3                       2                  8                     NaN
# 4                       2                  8                     NaN
#
#    product_id  add_to_cart_order  reordered _merge
# 0         196                  1          0   both
# 1       14084                  2          0   both
# ...

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# They have the matching column of product_id which I will use as the key column, since the df_ords_comb has more values we will use a how = inner and indicator = True

# %%
#test merge
pd.merge(df_ords_comb , df_prods, on = ['product_id'] , how = 'inner' , indicator = 'merge' )
# Out:
#           Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0                    0             0   2539329        1             1
# 1                    0             0   2539329        1             1
# 2                    0             0   2539329        1             1
# 3                    0             0   2539329        1             1
# 4                    0             0   2539329        1             1
# ...                ...           ...       ...      ...           ...
# 32404854       3421081       3421081   2977660   206209            13
# 32404855       3421081       3421081   2977660   206209            13
# 32404856       3421081       3421081   2977660   206209            13
# 32404857       3421081       3421081   2977660   206209            13
# 32404858       3421081       3421081   2977660   206209            13
#
#           orders_day_of_the_week  order_hour_of_day  days_since_prior_order  \
# ...

# %%
#actual merge
df_ords_prods_mergd = df_ords_comb.merge(df_prods, on = ['product_id'] , indicator = 'merge')

# %%
df_ords_prods_mergd.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             0             0   2539329        1             1
# 2             0             0   2539329        1             1
# 3             0             0   2539329        1             1
# 4             0             0   2539329        1             1
#
#    orders_day_of_the_week  order_hour_of_day  days_since_prior_order  \
# 0                       2                  8                     NaN
# 1                       2                  8                     NaN
# 2                       2                  8                     NaN
# 3                       2                  8                     NaN
# 4                       2                  8                     NaN
#
#    product_id  add_to_cart_order  reordered _merge  Unnamed: 0_y  \
# 0         196                  1          0   both           195
# ...

# %%
df_ords_prods_mergd.drop(['Unnamed: 0.1','Unnamed: 0_x','_merge','Unnamed: 0_y'],axis=1, inplace=True)

# %%
df_ords_prods_mergd
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 0          2539329        1             1                       2
# 1          2539329        1             1                       2
# 2          2539329        1             1                       2
# 3          2539329        1             1                       2
# 4          2539329        1             1                       2
# ...            ...      ...           ...                     ...
# 32404854   2977660   206209            13                       1
# 32404855   2977660   206209            13                       1
# 32404856   2977660   206209            13                       1
# 32404857   2977660   206209            13                       1
# 32404858   2977660   206209            13                       1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# ...

# %%
df_ords_prods_mergd['merge'].value_counts()
# Out:
# merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
#export to pkl file
df_ords_prods_mergd.to_pickle(os.path.join(path, '02 Data' , 'Prepared Data' , 'orders_products_.pkl'))
