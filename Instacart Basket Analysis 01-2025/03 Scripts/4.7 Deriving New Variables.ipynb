# %%
#importing libraries and data
import pandas as pd
import numpy as np
import os

# %%
#creating path for import
path = r'C:\Users\Stugots\Desktop\Bootcamp Stuff\Intro to Python\Instacart Basket Analysis 01-2025'

# %%
#importing data as dataframe
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data' , 'Prepared Data', 'orders_products_.pkl'))

# %%
df_ords_prods_merged
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 0          2539329        1             1                       2
# 1          2539329        1             1                       2
# 2          2539329        1             1                       2
# 3          2539329        1             1                       2
# 4          2539329        1             1                       2
# ...            ...      ...           ...                     ...
# 32404854   2977660   206209            13                       1
# 32404855   2977660   206209            13                       1
# 32404856   2977660   206209            13                       1
# 32404857   2977660   206209            13                       1
# 32404858   2977660   206209            13                       1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# ...

# %%
# creating a subset
df = df_ords_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
#defining the new function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
#applying function to the data frame
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Stugots\AppData\Local\Temp\ipykernel_18048\3453640589.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    673183
# Low-range product    314392
# High range            12425
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
#i have no idea why I am receiving receiving different results than what is shown in the reading.

# %%
#creating the same if/then but using the df.loc() function 
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Stugots\AppData\Local\Temp\ipykernel_18048\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts()
# Out:
# price_range_loc
# Mid-range product     673183
# Low-range product     314392
# High-range product     12425
# Name: count, dtype: int64

# %%
df_ords_prods_merged['orders_day_of_the_week'].value_counts(dropna = False)
# Out:
# orders_day_of_the_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
#using a for-loop to create a busiest day column  
result = []

for value in df_ords_prods_merged["orders_day_of_the_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merged['busiest_day'] = result

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
#Beginning of exercise 4.7
#using for-loop to create new busiest days column
results = []

for value in df_ords_prods_merged["orders_day_of_the_week"]:
  if value == 0 or value == 1:
    results.append("Busiest days")
  elif value == 4 or value == 3:
    results.append("Least busy")
  else:
    results.append("Regularly busy")

# %%
results
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
# ...

# %%
#creating the new column and adding our new list to the column
df_ords_prods_merged['busiest_days'] = results

# %%
#checking the value counts to make sure it worked
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy    12916111
# Busiest days      11864412
# Least busy         7624336
# Name: count, dtype: int64

# %%
#total outputs matches the number of rows in the dataframe so it appears to have worked correctly

# %%
#checking value counts to identify busiest times of day 
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
#create a for-loop to categorize the hours of the day column into the 3 categories 
result_2 = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value in [10,11,14,15,13,12,16,9]:
    result_2.append("Most Orders")
  elif value in [17,8,18,19,20,7,21,22]:
    result_2.append("Average Orders")
  else:
    result_2.append("Fewest Orders")

# %%
#checking new list
result_2
# Out:
# ['Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
# ...

# %%
#adding list to new column
df_ords_prods_merged['busiest_period_of_day'] = result_2

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2539329        1             1                       2                  8
# 2   2539329        1             1                       2                  8
# 3   2539329        1             1                       2                  8
# 4   2539329        1             1                       2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most Orders       21118071
# Average Orders     9997651
# Fewest Orders      1289137
# Name: count, dtype: int64

# %%
#total count equals total rows in dataframe so it appears to have worked correctly

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data' , 'Prepared Data' , 'orders_products_merged_newcolumns.pkl'))
