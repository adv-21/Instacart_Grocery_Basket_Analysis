# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
#creating path for easier import of data
path = r'C:\Users\Stugots\Desktop\Bootcamp Stuff\Intro to Python\Instacart Basket Analysis 01-2025'

# %%
#importing data as dataframe
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data' , 'Prepared Data', 'orders_products_merged_newcolumns.pkl'))

# %%
# creating a subset
df = ords_prods_merge[:1000000]

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2539329        1             1                       2                  8
# 2   2539329        1             1                       2                  8
# 3   2539329        1             1                       2                  8
# 4   2539329        1             1                       2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
#grouping by product_name column
df.groupby('product_name')

# %%
#grouping by deptartment_id to get the mean order numbers per dept.
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
#same thing using different syntax
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean' , 'min' , 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %%
#Creating new column to show max orders for each customer
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
#checking to make sure it worked
ords_prods_merge.head(60)
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0    2539329        1             1                       2
# 1    2539329        1             1                       2
# 2    2539329        1             1                       2
# 3    2539329        1             1                       2
# 4    2539329        1             1                       2
# 5    2398795        1             2                       3
# 6    2398795        1             2                       3
# 7    2398795        1             2                       3
# 8    2398795        1             2                       3
# 9    2398795        1             2                       3
# 10   2398795        1             2                       3
# 11    473747        1             3                       3
# 12    473747        1             3                       3
# 13    473747        1             3                       3
# 14    473747        1             3                       3
# ...

# %%
#removing the max number of rows displayed so .head(100) will show all 100 lines
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0    2539329        1             1                       2
# 1    2539329        1             1                       2
# 2    2539329        1             1                       2
# 3    2539329        1             1                       2
# 4    2539329        1             1                       2
# 5    2398795        1             2                       3
# 6    2398795        1             2                       3
# 7    2398795        1             2                       3
# 8    2398795        1             2                       3
# 9    2398795        1             2                       3
# 10   2398795        1             2                       3
# 11    473747        1             3                       3
# 12    473747        1             3                       3
# 13    473747        1             3                       3
# 14    473747        1             3                       3
# ...

# %%
#creating loyalty flag
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#checking count values to make sure it worked
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id','loyalty_flag','order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...
